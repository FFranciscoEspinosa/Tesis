# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import hamming
import gudhi as gd
import seaborn as sns
from statistics import mode
import multiprocessing
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import gudhi as gd
from scipy.spatial.distance import hamming
import plotly.graph_objs as go
import networkx as nx
import plotly.graph_objects as go
import plotly.io as pio
from networkx.utils import not_implemented_for, pairwise
from concurrent.futures import ThreadPoolExecutor, as_completed

# %% [markdown]
# <h3>Dos funciones para obtener los data frames de presencia</h3>

# %%
def get_info_by_pathway_and_all_genomes_directions(info):
    data_frames={}
    pathways=set()
    directions={}
    genome_directions={}
    for i in range(info.shape[0]):
        #Revisar si se debe separar esto
        #pathway=info.loc[i,0].split('|')[0].strip('\ufeff')
        pathway=info.loc[i,0].split('|')[0]
        if pathway not in directions.keys():
            directions[pathway]=[i]
        else:
            directions[pathway].append(i)
        #Se cambia la primer columna, para tener los genes
        gen_with_number=info.loc[i,0].split('|')[2]
        gen=gen_with_number[0:gen_with_number.rfind('_')]
        info.loc[i,0]=gen
        #Se obtienen los genomas
        genome=info.loc[i,1].split('|')[2]
        if genome not in genome_directions.keys():
            genome_directions[genome]=[i]
        else:
            genome_directions[genome].append(i)

    
    for pathway in directions.keys():
        data_frames[pathway]=info.loc[directions[pathway],:]
    return data_frames,genome_directions

# %%
def get_df_by_pathway(info_by_pathway_and_genomes_directions):
    info_by_pathway=info_by_pathway_and_genomes_directions[0]
    genomes_directions=info_by_pathway_and_genomes_directions[1]
    df_by_pathway={}

    for path in info_by_pathway.keys():
        info_path=info_by_pathway[path]
        genes=set(info_by_pathway[path][0].values)
        df=pd.DataFrame(index=genomes_directions.keys(),columns=list(genes))
        df.index.name=path
        
        for gen in genes:
            info_path_and_gen=info_path[info_path[0]==gen]
            for genom in genomes_directions.keys():
                direction=set(genomes_directions[genom]) & set(info_path_and_gen.index) 
                genomes_per_gen=info_path_and_gen.loc[list(direction)]
                uniq_genomes_per_gen=genomes_per_gen[1].drop_duplicates()
                df.loc[genom,gen]=uniq_genomes_per_gen.shape[0]
        df_by_pathway[path]=df.sort_index()
    return df_by_pathway

# %% [markdown]
# <h3>Funciones para dar peso</h3>

# %%
def get_mode(df):
    arr=[]
    for i in df.values:
        for j in i:
            if j !=0:
                arr.append(j)
    return mode(arr)

# %%
def get_weights(presence):
    mode=get_mode(presence)
    #peso menor que moda
    piv=presence[presence<mode]
    presence[piv>0]=1
    #peso igual a moda
    presence[presence==mode]=2
    #peso mayor que moda
    presence[presence>mode]=3
    return presence

# %% [markdown]
# <h2>Funciones para crear matrices de distancia,los complejos simpliciales</h2>

# %%
# Let's assume that "population" is a numpy ndarray with your genomes as rows.
def calculate_hamming_matrix(population):
    # Number of genomes
    num_genomes = population.shape[0]
    # Create an empty matrix for Hamming distances
    hamming_matrix = np.zeros((num_genomes, num_genomes), dtype=int)
   # Calculate the Hamming distance between each pair of genomes
    for i in range(num_genomes):
        for j in range(i+1, num_genomes):  # j=i+1 to avoid calculating the same distance twice
            # The Hamming distance is multiplied by the number of genes to convert it into an absolute distance
            distance = hamming(population[i], population[j]) * len(population[i])
            hamming_matrix[i, j] = distance
            hamming_matrix[j, i] = distance  # The matrix is symmetric
    
    return hamming_matrix

# %%
def create_complex(distance_matrix2):
    # Create the Rips simplicial complex from the distance matrix
    rips_complex = gd.RipsComplex(distance_matrix=distance_matrix2)
    # Create the simplex tree from the Rips complex with a maximum dimension of 3
    simplex_tree = rips_complex.create_simplex_tree(max_dimension=2)
    # Compute the persistence of the simplicial complex
    persistence = simplex_tree.persistence()
    # Return the persistence diagram or barcode
    return persistence, simplex_tree

# %%
def get_complex_by_pathways(path_dict):
    complex_path_dict={}
    for path in path_dict.keys():
        complex_path_dict[path]=create_complex(calculate_hamming_matrix(path_dict[path].values))
    return complex_path_dict

# %%
def plot_all_bar_code_pathways(complex_pathways):
    for i in complex_pathways.keys():
        gd.plot_persistence_barcode(complex_pathways[i][0],legend=True)
        plt.title(f"{i}" )

# %% [markdown]
# <h2>Funciones para obtener los uno-hoyos</h2>

# %%
def dict_holes_to_names(holes):
    key=list(df_by_pathway.keys())[0]
    df=df_by_pathway[key].copy(deep=True)
    df.reset_index(inplace=True)
    true_name_holes=[]
    for hole in holes:
        true_name_holes.append(list(df.loc[hole,:]['index']))
    return true_name_holes

# %%
def minimum_cycle_basis(G, weight=None, total=None):
    """Returns a minimum weight cycle basis for G

    Minimum weight means a cycle basis for which the total weight
    (length for unweighted graphs) of all the cycles is minimum.

    Parameters
    ----------
    G : NetworkX Graph
    weight: string
        name of the edge attribute to use for edge weights

    Returns
    -------
    A list of cycle lists.  Each cycle list is a list of nodes
    which forms a cycle (loop) in G. Note that the nodes are not
    necessarily returned in a order by which they appear in the cycle

    Examples
    --------
    >>> G = nx.Graph()
    >>> nx.add_cycle(G, [0, 1, 2, 3])
    >>> nx.add_cycle(G, [0, 3, 4, 5])
    >>> nx.minimum_cycle_basis(G)
    [[5, 4, 3, 0], [3, 2, 1, 0]]

    References:
        [1] Kavitha, Telikepalli, et al. "An O(m^2n) Algorithm for
        Minimum Cycle Basis of Graphs."
        http://link.springer.com/article/10.1007/s00453-007-9064-z
        [2] de Pina, J. 1995. Applications of shortest path methods.
        Ph.D. thesis, University of Amsterdam, Netherlands

    See Also
    --------
    simple_cycles, cycle_basis
    """
    # We first split the graph in connected subgraphs
    return sum(
        (_min_cycle_basis(G.subgraph(c), weight,total) for c in nx.connected_components(G)),
        [],
    )

def _min_cycle_basis(G, weight,total):
    cb = []
    cont=0
    # We  extract the edges not in a spanning tree. We do not really need a
    # *minimum* spanning tree. That is why we call the next function with
    # weight=None. Depending on implementation, it may be faster as well
    tree_edges = list(nx.minimum_spanning_edges(G, weight=None, data=False))
    chords = G.edges - tree_edges - {(v, u) for u, v in tree_edges}

    # We maintain a set of vectors orthogonal to sofar found cycles
    set_orth = [{edge} for edge in chords]
    while set_orth:
        if cont==total:
            break
        base = set_orth.pop()
        # kth cycle is "parallel" to kth vector in set_orth
        cycle_edges = _min_cycle(G, base, weight)
        cycle_found=[v for u, v in cycle_edges]

        if len(cycle_found)>3:
            cb.append(cycle_found)
            cont+=1

        # now update set_orth so that k+1,k+2... th elements are
        # orthogonal to the newly found cycle, as per [p. 336, 1]
        set_orth = [
            (
                {e for e in orth if e not in base if e[::-1] not in base}
                | {e for e in base if e not in orth if e[::-1] not in orth}
            )
            if sum((e in orth or e[::-1] in orth) for e in cycle_edges) % 2
            else orth
            for orth in set_orth
        ]
    return cb


def _min_cycle(G, orth, weight):
    """
    Computes the minimum weight cycle in G,
    orthogonal to the vector orth as per [p. 338, 1]
    Use (u, 1) to indicate the lifted copy of u (denoted u' in paper).
    """
    Gi = nx.Graph()

    # Add 2 copies of each edge in G to Gi.
    # If edge is in orth, add cross edge; otherwise in-plane edge
    for u, v, wt in G.edges(data=weight, default=1):
        if (u, v) in orth or (v, u) in orth:
            Gi.add_edges_from([(u, (v, 1)), ((u, 1), v)], Gi_weight=wt)
        else:
            Gi.add_edges_from([(u, v), ((u, 1), (v, 1))], Gi_weight=wt)

    # find the shortest length in Gi between n and (n, 1) for each n
    # Note: Use "Gi_weight" for name of weight attribute
    spl = nx.shortest_path_length
    lift = {n: spl(Gi, source=n, target=(n, 1), weight="Gi_weight") for n in G}

    # Now compute that short path in Gi, which translates to a cycle in G
    start = min(lift, key=lift.get)
    end = (start, 1)
    min_path_i = nx.shortest_path(Gi, source=start, target=end, weight="Gi_weight")

    # Now we obtain the actual path, re-map nodes in Gi to those in G
    min_path = [n if n in G else n[0] for n in min_path_i]

    # Now remove the edges that occur two times
    # two passes: flag which edges get kept, then build it
    edgelist = list(pairwise(min_path))
    edgeset = set()
    for e in edgelist:
        if e in edgeset:
            edgeset.remove(e)
        elif e[::-1] in edgeset:
            edgeset.remove(e[::-1])
        else:
            edgeset.add(e)

    min_edgelist = []
    for e in edgelist:
        if e in edgeset:
            min_edgelist.append(e)
            edgeset.remove(e)
        elif e[::-1] in edgeset:
            min_edgelist.append(e[::-1])
            edgeset.remove(e[::-1])

    return min_edgelist

# %%
def find_all_cycles(complex_path):
    persistence,simplex_tree=complex_pathways[complex_path]
    born_and_number = born_filtraton_value_holes(persistence)
    G=nx.Graph()
    born=born_and_number.keys()
    ciclos_dep=set()
    filtration=0
    for simplex, filt in simplex_tree.get_filtration():
        #if len(ciclos_dep)==num_holes:
         #   break
        
        if filtration!=filt and filtration in born:
            number=born_and_number[filtration]
            print('se buscan ciclos en el tiempo', filt,'para',complex_path)
            ciclos=minimum_cycle_basis(G,total=number)
            for ciclo in ciclos:
                if len(ciclo)>3:
                    print('Se encontró el ciclo',ciclo,'en el tiempo', filtration,'para',complex_path)
                    ciclos_dep.add(tuple(ciclo))
                    #Se llena el hoyo
                    for i in ciclo:
                        for j in ciclo:
                            G.add_edge(i,j)
                            
            
        filtration=filt
        
        if len(simplex)==2:
            G.add_edge(simplex[0], simplex[1])


    #direc='pseudomonas_'+complex_path+'.txt'
    #f = open(direc, "a")
    #f.write(str(ciclos_dep))
    #f.close()
        

    return [complex_path,dict_holes_to_names(ciclos_dep)]

# %%
def born_filtraton_value_holes(persistence):
    born=[]
    for bar in persistence:
        if bar[0]==1:
            born.append(bar[1][0])
            
    born_and_number=set([(x,born.count(x)) for x  in born])

    return dict(born_and_number)

# %%
def get_holes_by_pathways(complex_by_path):
    llaves=complex_by_path.keys()
    with multiprocessing.Pool() as pool:
        # Mapear los ítems a la función process_item en paralelo
        results = pool.map(find_all_cycles,llaves)
    return dict(results)

# %% [markdown]
# <h2>EJECUCIÓN:Se pide un score minimo</h2>

# %%
info=pd.read_csv('data/pscpPseudo.blast',sep='\t',header=None)
minimum_score=100
info=info[info[11]>=minimum_score]
info.reset_index(drop=True,inplace=True)
info=info.loc[:,0:1]

# %%
info_by_pathway_and_genomes_directions=get_info_by_pathway_and_all_genomes_directions(info)
df_by_pathway=get_df_by_pathway(info_by_pathway_and_genomes_directions)
complex_pathways=get_complex_by_pathways(df_by_pathway)

# %%
holes=get_holes_by_pathways(complex_by_pathways)
# Out:
# se buscan ciclos en el tiempo 2.0se buscan ciclos en el tiempose buscan ciclos en el tiempo  para2.0   2.0PYR_THR_AA para
# para  OXALACETATE_AMINOACIDSALPHAKETOGLUTARATE_AMINOACIDS
#
# se buscan ciclos en el tiempo 2.0 para 3PGA_AMINOACIDS
# se buscan ciclos en el tiempo 2.0 para E4P_AMINO_ACIDS
# se buscan ciclos en el tiempo 2.0 para R5P_AMINOACIDS
# se buscan ciclos en el tiempo 2.0 para TCA
# se buscan ciclos en el tiempo 2.0 para Glycolysis
# Se encontró el ciclo [175, 172, 48, 1] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [182, 138, 128, 96] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [79, 90, 38, 1] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [40, 87, 18, 1] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [161, 121, 58, 133] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [133, 8, 5, 113, 33, 22, 32, 14] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [197, 164, 176, 1] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [165, 19, 38, 1] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [197, 128, 18, 1] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [176, 41, 48, 1] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [197, 164, 28, 67] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [79, 32, 14, 48] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [48, 133, 18, 1] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [50, 8, 18, 1] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [176, 68, 165, 1] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [48, 55, 38, 1] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [197, 67, 63, 1] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [38, 36, 26, 1] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [65, 37, 20, 137] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [77, 203, 57, 153] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [150, 186, 85, 137] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [112, 91, 24, 137] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [30, 88, 24, 137] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [88, 51, 49, 141] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [85, 23, 30, 137] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [85, 115, 20, 137] en el tiempo 1.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# se buscan ciclos en el tiempo 3.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [177, 84, 22, 8] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [47, 56, 81, 46, 30, 37] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [96, 129, 89, 154] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [154, 89, 41, 26] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [154, 177, 13, 26] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [177, 84, 68, 13] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [28, 123, 25, 37] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [64, 214, 18, 76] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [63, 103, 47, 37] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [61, 11, 28, 37] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [92, 31, 38, 13] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [150, 17, 16, 97] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [12, 150, 6, 0] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [173, 74, 95, 132] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [173, 144, 54, 132] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [54, 144, 40, 1] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [191, 149, 187, 200] en el tiempo 1.0 para PYR_THR_AA
# Se encontró el ciclo [149, 73, 119, 193] en el tiempo 1.0 para PYR_THR_AA
# se buscan ciclos en el tiempo 3.0 para PYR_THR_AA
# Se encontró el ciclo [176, 30, 121, 0] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [108, 152, 68, 27] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [138, 119, 121, 0] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [151, 76, 23, 47] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [65, 76, 42, 56] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [23, 42, 44, 5, 12, 4] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [33, 2, 6, 19] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [52, 178, 43, 23] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [30, 11, 34, 61, 144, 68, 27] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [176, 11, 25, 0] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [149, 201, 73, 64] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [121, 69, 64, 25] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [64, 137, 11, 25] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [184, 201, 73, 57] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [137, 64, 14, 56] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [150, 41, 137, 56] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [57, 137, 41, 10] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [160, 108, 121, 0] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [108, 69, 28, 27] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [160, 108, 27, 1] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [111, 113, 43, 34] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [176, 30, 27, 1] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [100, 77, 27, 10] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [138, 24, 25, 0] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [78, 52, 4, 1] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [158, 56, 137, 28] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [69, 73, 57, 28] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [47, 157, 7, 27] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [34, 43, 23, 11] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [103, 7, 27, 1] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [43, 113, 42, 23] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [41, 23, 4, 1] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [160, 20, 25, 0] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [176, 32, 123, 36, 26, 42, 23, 4] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [176, 1, 160, 0] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [103, 70, 41, 1] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [160, 20, 41, 1] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [137, 23, 42, 56] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [27, 47, 4, 1] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [138, 19, 6, 0] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [24, 23, 11, 25] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [108, 119, 47, 27] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [176, 11, 41, 1] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [176, 4, 138, 0] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [158, 59, 57, 28] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [57, 28, 27, 10] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [10, 183, 4, 1] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [49, 70, 20, 25] en el tiempo 1.0 para OXALACETATE_AMINOACIDS
# se buscan ciclos en el tiempo 3.0 para OXALACETATE_AMINOACIDS
# Se encontró el ciclo [75, 25, 11, 66] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [111, 100, 129, 183, 0, 48] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [22, 33, 17, 61] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [91, 178, 42, 30] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [75, 128, 9, 80] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [178, 39, 41, 14] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [129, 100, 203, 77] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [68, 19, 12, 43] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [75, 114, 124, 200, 66] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [183, 9, 45, 0] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [42, 66, 121, 151, 23] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [177, 61, 22, 32] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [42, 39, 28, 66] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [181, 152, 42, 66] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [182, 197, 38, 2] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [212, 183, 77, 53] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [188, 66, 42, 23] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# Se encontró el ciclo [67, 3, 53, 212, 0] en el tiempo 2.0 para ALPHAKETOGLUTARATE_AMINOACIDS
# se buscan ciclos en el tiempo 4.0 para ALPHAKETOGLUTARATE_AMINOACIDS

# %%
holes['Glycolysis']
# Out:
# [['666666.100019', '666666.100028', '666666.100027', '666666.100006'],
#  ['666666.100023', '666666.100031', '666666.100007', '666666.100004'],
#  ['666666.100023', '666666.100030', '666666.100006', '666666.100004']]

# %%
df_by_pathway['TCA'].to_csv('TCA.csv')

# %%
df_by_pathway['Glycolysis'].index.name='G'
df_by_pathway['Glycolysis']
# Out:
#               glyceraldehyde3phosphate_dehydrogenase  \
# G
# 666666.100004                                      1
# 666666.100005                                      1
# 666666.100006                                      1
# 666666.100007                                      1
# 666666.100008                                      1
# 666666.100010                                      1
# 666666.100019                                      1
# 666666.100020                                      1
# 666666.100023                                      1
# 666666.100025                                      1
# 666666.100026                                      1
# 666666.100027                                      1
# 666666.100028                                      1
# 666666.100029                                      1
# 666666.100030                                      1
# 666666.100031                                      1
# 666666.100032                                      1
# 666666.100040                                      1
# 666666.100041                                      1
# 666666.100042                                      0
# 666666.100044                                      1
#
#               Fructose_biphosphate_aldolase Glucose_kinase  \
# G
# 666666.100004                             1              4
# 666666.100005                             1              5
# 666666.100006                             1              4
# 666666.100007                             1              4
# 666666.100008                             1              3
# 666666.100010                             1              4
# 666666.100019                             1              6
# 666666.100020                             1              8
# 666666.100023                             1              6
# 666666.100025                             1              2
# 666666.100026                             1              7
# 666666.100027                             1              4
# 666666.100028                             1              3
# 666666.100029                             0              1
# 666666.100030                             1              7
# 666666.100031                             1              5
# 666666.100032                             1              7
# 666666.100040                             2              5
# 666666.100041                             2              3
# 666666.100042                             1              3
# 666666.100044                             1              6
#
#               Triosephosphate_isomerase phosphoglycerate_kinase  \
# G
# 666666.100004                         1                       2
# 666666.100005                         1                       2
# 666666.100006                         1                       2
# 666666.100007                         1                       2
# 666666.100008                         1                       2
# 666666.100010                         1                       2
# 666666.100019                         1                       2
# 666666.100020                         1                       2
# 666666.100023                         1                       2
# 666666.100025                         2                       2
# 666666.100026                         1                       2
# 666666.100027                         1                       2
# 666666.100028                         1                       2
# 666666.100029                         1                       2
# 666666.100030                         1                       2
# 666666.100031                         1                       2
# 666666.100032                         1                       2
# 666666.100040                         1                       2
# 666666.100041                         1                       2
# 666666.100042                         0                       1
# 666666.100044                         1                       2
#
#               phosphoglycerate_mutase Phosphofructokinase  \
# G
# 666666.100004                       5                   1
# 666666.100005                       4                   1
# 666666.100006                       3                   1
# 666666.100007                       4                   1
# 666666.100008                       5                   1
# 666666.100010                       4                   2
# 666666.100019                       3                   2
# 666666.100020                       4                   2
# 666666.100023                       5                   3
# 666666.100025                       6                   2
# 666666.100026                       6                   3
# 666666.100027                       3                   1
# 666666.100028                       3                   2
# 666666.100029                       2                   0
# 666666.100030                       3                   3
# 666666.100031                       4                   3
# 666666.100032                       4                   3
# 666666.100040                       3                   2
# 666666.100041                       2                   3
# 666666.100042                       3                   1
# 666666.100044                       3                   3
#
#               Glucose_6_phosphate_isomerase Pyruvate_kinase enolase
# G
# 666666.100004                             0               1       1
# 666666.100005                             0               1       1
# 666666.100006                             0               1       1
# 666666.100007                             0               1       1
# 666666.100008                             0               1       1
# 666666.100010                             0               1       1
# 666666.100019                             0               1       1
# 666666.100020                             0               1       1
# 666666.100023                             0               1       1
# 666666.100025                             0               1       1
# 666666.100026                             0               1       1
# 666666.100027                             1               1       1
# 666666.100028                             1               1       1
# 666666.100029                             0               0       0
# 666666.100030                             0               1       1
# 666666.100031                             0               1       1
# 666666.100032                             0               1       1
# 666666.100040                             0               1       1
# 666666.100041                             1               1       1
# 666666.100042                             0               0       0
# 666666.100044                             0               1       1
